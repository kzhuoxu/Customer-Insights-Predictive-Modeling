# %% [markdown]
# # Segmentation
# Unsupervised Learning

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import silhouette_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
notebook_path = Path.cwd()
project_root = notebook_path.parent
sys.path.insert(0, str(project_root))

# print(f"Project Root (added to sys.path): {project_root}")

# %%
from src import config
from src.data_loader import load_census_data

raw_df = load_census_data(
    data_path=config.DATA_FILE,
    columns_path=config.COLUMNS_FILE
)
raw_df.head()
# Out:
# Data loaded and initial cleaning complete.
# Dataset shape: (199523, 42)
#    age                 class_of_worker  detailed_industry_recode  \
# 0   73                 Not in universe                         0
# 1   58  Self-employed-not incorporated                         4
# 2   18                 Not in universe                         0
# 3    9                 Not in universe                         0
# 4   10                 Not in universe                         0
#
#    detailed_occupation_recode                   education  wage_per_hour  \
# 0                           0        High school graduate              0
# 1                          34  Some college but no degree              0
# 2                           0                  10th grade              0
# 3                           0                    Children              0
# 4                           0                    Children              0
#
#   enroll_in_edu_inst_last_wk   marital_stat          major_industry_code  \
# 0            Not in universe        Widowed  Not in universe or children
# 1            Not in universe       Divorced                 Construction
# 2                High school  Never married  Not in universe or children
# 3            Not in universe  Never married  Not in universe or children
# 4            Not in universe  Never married  Not in universe or children
#
#                  major_occupation_code  ... country_of_birth_father  \
# 0                      Not in universe  ...           United-States
# 1  Precision production craft & repair  ...           United-States
# 2                      Not in universe  ...                 Vietnam
# 3                      Not in universe  ...           United-States
# 4                      Not in universe  ...           United-States
#
#   country_of_birth_mother country_of_birth_self  \
# 0           United-States         United-States
# 1           United-States         United-States
# 2                 Vietnam               Vietnam
# 3           United-States         United-States
# 4           United-States         United-States
#
#                           citizenship own_business_or_self_employed  \
# 0   Native- Born in the United States                             0
# 1   Native- Born in the United States                             0
# 2  Foreign born- Not a citizen of U S                             0
# 3   Native- Born in the United States                             0
# 4   Native- Born in the United States                             0
#
#   fill_inc_questionnaire_for_veterans_admin  veterans_benefits  \
# 0                           Not in universe                  2
# 1                           Not in universe                  2
# 2                           Not in universe                  2
# 3                           Not in universe                  0
# 4                           Not in universe                  0
#
#    weeks_worked_in_year  year label
# 0                     0    95     0
# 1                    52    94     0
# 2                     0    95     0
# 3                     0    94     0
# 4                     0    94     0
#
# [5 rows x 42 columns]

# %%
print(config.TARGET_VARIABLE)
# Out:
# label

# %% [markdown]
# Separate the Target, Features and Weights

# %%
X = raw_df.drop(columns=[config.TARGET_VARIABLE, 'weight'])
y = raw_df[config.TARGET_VARIABLE]
weights = raw_df['weight']

# %% [markdown]
# Feature Engineering

# %%
from src.feature_engineering import create_features

X_featured = create_features(X)

print(X_featured.shape[1])
print(X_featured.columns.tolist())
# Out:
# Mapping numeric codes to string labels...
# Dropping unused columns: ['detailed_industry_recode', 'detailed_occupation_recode', 'year', 'capital_gains', 'capital_losses', 'dividends_from_stocks']
# Feature engineering complete. New columns added.
# 46
# ['age', 'class_of_worker', 'education', 'wage_per_hour', 'enroll_in_edu_inst_last_wk', 'marital_stat', 'major_industry_code', 'major_occupation_code', 'race', 'hispanic_origin', 'sex', 'member_of_a_labor_union', 'reason_for_unemployment', 'full_or_part_time_employment_stat', 'tax_filer_stat', 'region_of_previous_residence', 'state_of_previous_residence', 'detailed_household_and_family_stat', 'detailed_household_summary_in_household', 'migration_code_change_in_msa', 'migration_code_change_in_reg', 'migration_code_move_within_reg', 'live_in_this_house_1_year_ago', 'migration_prev_res_in_sunbelt', 'num_persons_worked_for_employer', 'family_members_under_18', 'country_of_birth_father', 'country_of_birth_mother', 'country_of_birth_self', 'citizenship', 'own_business_or_self_employed', 'fill_inc_questionnaire_for_veterans_admin', 'veterans_benefits', 'weeks_worked_in_year', 'log_capital_gains', 'log_capital_losses', 'log_dividends_from_stocks', 'net_capital_gain', 'has_investment_income', 'employment_status', 'age_squared', 'age_group', 'education_group', 'marital_age_interaction', 'education_age_interaction', 'immigrant_status']

# %% [markdown]
# ## Feature Selection

# %%
SEGMENTATION_FEATURES = [
    # Core Demographics
    'age', 'sex', 'race',
    # Household Composition
    'marital_stat', 'family_members_under_18', 'tax_filer_stat',
    # Education & Careers
    'education_group', 'major_occupation_code', 'major_industry_code',
    # Work Intensity
    'employment_status', 'weeks_worked_in_year',
    # Financial Profile
    'wage_per_hour', 'log_capital_gains', 'log_capital_losses', 'log_dividends_from_stocks',
    'has_investment_income', 'own_business_or_self_employed',
    # Nativity & Migration
    'citizenship', 'live_in_this_house_1_year_ago',
    # Veteran Status
    'veterans_benefits'
]

X_segment = X_featured[SEGMENTATION_FEATURES].copy()
SEG_NUMERICAL_COLS = X_segment.select_dtypes(include=np.number).columns.tolist()
SEG_CATEGORICAL_COLS = X_segment.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
print(f"Numerical Features ({len(SEG_NUMERICAL_COLS)}): {SEG_NUMERICAL_COLS}")
print(f"Categorical Features ({len(SEG_CATEGORICAL_COLS)}): {SEG_CATEGORICAL_COLS}")
# Out:
# Numerical Features (7): ['age', 'weeks_worked_in_year', 'wage_per_hour', 'log_capital_gains', 'log_capital_losses', 'log_dividends_from_stocks', 'has_investment_income']
# Categorical Features (13): ['sex', 'race', 'marital_stat', 'family_members_under_18', 'tax_filer_stat', 'education_group', 'major_occupation_code', 'major_industry_code', 'employment_status', 'own_business_or_self_employed', 'citizenship', 'live_in_this_house_1_year_ago', 'veterans_benefits']

# %% [markdown]
# ## Preprocessing
# ### with FAMD

# %%
import prince

famd_preprocessor = ColumnTransformer(
    [('scaler', StandardScaler(), SEG_NUMERICAL_COLS)],
    remainder='passthrough'
)
famd_preprocessor.set_output(transform='pandas')

N_COMPONENTS = 15

famd_pipeline = Pipeline(steps=[
    ('preprocessor', famd_preprocessor),
    ('famd', prince.FAMD(
        n_components=N_COMPONENTS,
        n_iter=5,
        random_state=config.RANDOM_STATE
    ))
])

print("Fitting FAMD and transforming data...")
X_processed_famd = famd_pipeline.fit_transform(X_segment)
print(f"Processed Feature Shape after FAMD: {X_processed_famd.shape}")
# Out:
# Fitting FAMD and transforming data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 21
#      11 famd_pipeline = Pipeline(steps=[
#      12     ('preprocessor', famd_preprocessor),
#      13     ('famd', prince.FAMD(
#    (...)     17     ))
#      18 ])
#      20 print("Fitting FAMD and transforming data...")
# ---> 21 X_processed_famd = famd_pipeline.fit_transform(X_segment)
#      22 print(f"Processed Feature Shape after FAMD: {X_processed_famd.shape}")
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/pipeline.py:731, in Pipeline.fit_transform(self, X, y, **params)
#     725 last_step_params = self._get_metadata_for_step(
#     726     step_idx=len(self) - 1,
#     727     step_params=routed_params[self.steps[-1][0]],
#     728     all_params=params,
#     729 )
#     730 if hasattr(last_step, "fit_transform"):
# --> 731     return last_step.fit_transform(
#     732         Xt, y, **last_step_params["fit_transform"]
#     733     )
#     734 else:
#     735     return last_step.fit(Xt, y, **last_step_params["fit"]).transform(
#     736         Xt, **last_step_params["transform"]
#     737     )
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/utils/_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/utils.py:28, in check_is_dataframe_input.<locals>.wrapper(*args, **kwargs)
#      24 if not isinstance(X, pd.DataFrame):
#      25     raise ValueError(
#      26         f"The X argument must be a pandas DataFrame, but got {type(X).__name__}"
#      27     )
# ---> 28 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/pca.py:251, in PCA.fit_transform(self, X, y, as_array)
#     242 """A faster way to fit/transform.
#     243
#     244 This methods produces exactly the same result as calling `fit(X)` followed
#    (...)    248
#     249 """
#     250 self._check_input(X)
# --> 251 self.fit(X)
#     252 rc = self.row_coordinates(X)
#     253 return rc.to_numpy() if as_array else rc
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/utils.py:28, in check_is_dataframe_input.<locals>.wrapper(*args, **kwargs)
#      24 if not isinstance(X, pd.DataFrame):
#      25     raise ValueError(
#      26         f"The X argument must be a pandas DataFrame, but got {type(X).__name__}"
#      27     )
# ---> 28 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/famd.py:74, in FAMD.fit(self, X, y)
#      71 X_cat_oh_norm = X_cat_oh_norm.sparse.to_dense()
#      73 Z = pd.concat([X_num, X_cat_oh_norm], axis=1)
# ---> 74 super().fit(Z)
#      76 # Determine column_coordinates_
#      77 # This is based on line 184 in FactoMineR's famd.R file
#      78 rc = self.row_coordinates(X)
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/utils.py:28, in check_is_dataframe_input.<locals>.wrapper(*args, **kwargs)
#      24 if not isinstance(X, pd.DataFrame):
#      25     raise ValueError(
#      26         f"The X argument must be a pandas DataFrame, but got {type(X).__name__}"
#      27     )
# ---> 28 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/pca.py:83, in PCA.fit(self, X, y, sample_weight, column_weight, supplementary_columns)
#      74 @utils.check_is_dataframe_input
#      75 def fit(
#      76     self,
#    (...)     81     supplementary_columns=None,
#      82 ):
# ---> 83     self._check_input(X)
#      85     # Massage input
#      86     supplementary_columns = supplementary_columns or []
#
# File ~/anaconda3/lib/python3.12/site-packages/prince/famd.py:38, in FAMD._check_input(self, X)
#      36 def _check_input(self, X):
#      37     if self.check_input:
# ---> 38         sklearn.utils.check_array(X, dtype=[str, "numeric"])
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/utils/validation.py:1053, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1051         array = xp.astype(array, dtype, copy=False)
#    1052     else:
# -> 1053         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1054 except ComplexWarning as complex_warning:
#    1055     raise ValueError(
#    1056         "Complex data not supported\n{}\n".format(array)
#    1057     ) from complex_warning
#
# File ~/anaconda3/lib/python3.12/site-packages/sklearn/utils/_array_api.py:757, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     755     array = numpy.array(array, order=order, dtype=dtype)
#     756 else:
# --> 757     array = numpy.asarray(array, order=order, dtype=dtype)
#     759 # At this point array is a NumPy ndarray. We convert it to an array
#     760 # container that is consistent with the input's namespace.
#     761 return xp.asarray(array)
#
# KeyboardInterrupt:

# %%
famd_instance = famd_pipeline.named_steps['famd']
famd_instance.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0             36.528         7.39%                      7.39%
# 1             13.651         2.76%                     10.15%
# 2             13.142         2.66%                     12.81%
# 3             13.021         2.63%                     15.44%
# 4             12.688         2.57%                     18.00%
# 5             12.160         2.46%                     20.46%
# 6             11.722         2.37%                     22.83%
# 7             10.247         2.07%                     24.91%
# 8              9.837         1.99%                     26.90%
# 9              9.420         1.91%                     28.80%
# 10             8.856         1.79%                     30.59%
# 11             8.720         1.76%                     32.35%
# 12             8.518         1.72%                     34.08%
# 13             8.450         1.71%                     35.79%
# 14             8.317         1.68%                     37.47%

# %%
eigenvalues = famd_instance.eigenvalues_
total_inertia = sum(eigenvalues)
explained_inertia = [eig / total_inertia for eig in eigenvalues]

feature_contributions = famd_instance.column_coordinates_

# --- Detailed Analysis for Top Components ---

print("="*60)
print("--- Decoding FAMD Component 0 (The Primary Axis) ---")
print(f"This component explains {explained_inertia[0]:.2%} of the total variance.")
print("Top 10 features most influential for Component 0:")
# We display the actual coordinate values to see the direction of influence (positive/negative)
# but sort by the absolute value to find the strongest influencers.
display(feature_contributions[0].reindex(feature_contributions[0].abs().sort_values(ascending=False).index).head(10).to_frame(name='Coordinate on Component 0'))


print("\n" + "="*60)
print("--- Decoding FAMD Component 1 (The Secondary Axis) ---")
print(f"This component explains {explained_inertia[1]:.2%} of the total variance.")
print("Top 10 features most influential for Component 1:")
display(feature_contributions[1].reindex(feature_contributions[1].abs().sort_values(ascending=False).index).head(10).to_frame(name='Coordinate on Component 1'))


max_val = feature_contributions.abs().max().max()

# Apply the background gradient styling
styled_contributions = feature_contributions.style.background_gradient(
    cmap='bwr', vmin=-max_val, vmax=max_val
).format("{:.3f}")

print("\nFull Contribution Matrix of Features on FAMD Components:")
display(styled_contributions)
# Out:
# ============================================================
# --- Decoding FAMD Component 0 (The Primary Axis) ---
# This component explains 19.72% of the total variance.
# Top 10 features most influential for Component 0:
#                                     Coordinate on Component 0
# variable
# remainder__education_group                           0.827275
# remainder__tax_filer_stat                            0.784820
# remainder__family_members_under_18                   0.782623
# remainder__veterans_benefits                         0.763365
# remainder__major_occupation_code                     0.685969
# remainder__major_industry_code                       0.684872
# scaler__weeks_worked_in_year                         0.629978
# remainder__marital_stat                              0.505305
# scaler__age                                          0.331611
# remainder__employment_status                         0.297062
# ============================================================
# --- Decoding FAMD Component 1 (The Secondary Axis) ---
# This component explains 7.37% of the total variance.
# Top 10 features most influential for Component 1:
#                                   Coordinate on Component 1
# variable
# remainder__major_occupation_code                   0.566244
# remainder__major_industry_code                     0.463641
# remainder__education_group                         0.384369
# remainder__tax_filer_stat                          0.265474
# remainder__marital_stat                            0.250778
# scaler__has_investment_income                      0.039601
# remainder__citizenship                             0.038717
# remainder__veterans_benefits                       0.032360
# remainder__race                                    0.027605
# remainder__employment_status                       0.021015
# Full Contribution Matrix of Features on FAMD Components:
# <style type="text/css">
# #T_b3bb3_row0_col0, #T_b3bb3_row14_col2 {
b3bb3_row11_col3, #T_b3bb3_row11_col6, #T_b3bb3_row11_col7, #T_b3bb3_row11_col13, #T_b3bb3_row11_col14, #T_b3bb3_row14_col3, #T_b3bb3_row15_col3, #T_b3bb3_row15_col6, #T_b3bb3_row15_col7, #T_b3bb3_row15_col8, #T_b3bb3_row15_col10, #T_b3bb3_row15_col13, #T_b3bb3_row15_col14, #T_b3bb3_row16_col3, #T_b3bb3_row16_col4, #T_b3bb3_row16_col6, #T_b3bb3_row17_col0, #T_b3bb3_row17_col2, #T_b3bb3_row17_col7, #T_b3bb3_row17_col10, #T_b3bb3_row17_col11, #T_b3bb3_row17_col12, #T_b3bb3_row17_col13, #T_b3bb3_row18_col3, #T_b3bb3_row19_col3, #T_b3bb3_row19_col6, #T_b3bb3_row19_col7, #T_b3bb3_row19_col10, #T_b3bb3_row19_col12, #T_b3bb3_row19_col13, #T_b3bb3_row19_col14 {
#   background-color: #fffefe;
#   color: #000000;
# }
# #T_b3bb3_row0_col2, #T_b3bb3_row11_col11 {
#   background-color: #ffc2c2;
#   color: #000000;
# }
# #T_b3bb3_row0_col4, #T_b3bb3_row7_col7, #T_b3bb3_row7_col14, #T_b3bb3_row11_col9, #T_b3bb3_row14_col12, #T_b3bb3_row17_col6, #T_b3bb3_row18_col12, #T_b3bb3_row19_col2 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_b3bb3_row0_col5, #T_b3bb3_row6_col1, #T_b3bb3_row7_col1, #T_b3bb3_row7_col11, #T_b3bb3_row8_col14, #T_b3bb3_row9_col4, #T_b3bb3_row9_col5, #T_b3bb3_row9_col9, #T_b3bb3_row16_col9, #T_b3bb3_row18_col4, #T_b3bb3_row18_col5 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_b3bb3_row0_col6, #T_b3bb3_row0_col8, #T_b3bb3_row0_col9, #T_b3bb3_row1_col5, #T_b3bb3_row1_col11, #T_b3bb3_row1_col12, #T_b3bb3_row3_col1, #T_b3bb3_row4_col0, #T_b3bb3_row6_col4, #T_b3bb3_row6_col9, #T_b3bb3_row7_col0, #T_b3bb3_row7_col4, #T_b3bb3_row7_col5, #T_b3bb3_row7_col9, #T_b3bb3_row7_col10, #T_b3bb3_row9_col3, #T_b3bb3_row10_col1, #T_b3bb3_row10_col4, #T_b3bb3_row10_col9, #T_b3bb3_row10_col13, #T_b3bb3_row15_col1, #T_b3bb3_row15_col4, #T_b3bb3_row15_col5, #T_b3bb3_row15_col9, #T_b3bb3_row15_col11, #T_b3bb3_row15_col12, #T_b3bb3_row16_col0, #T_b3bb3_row16_col2, #T_b3bb3_row16_col5, #T_b3bb3_row16_col10, #T_b3bb3_row17_col1, #T_b3bb3_row17_col3, #T_b3bb3_row17_col8, #T_b3bb3_row18_col10, #T_b3bb3_row19_col9 {
#   background-color: #fffcfc;
#   color: #000000;
# }
# #T_b3bb3_row0_col11, #T_b3bb3_row1_col4, #T_b3bb3_row7_col2, #T_b3bb3_row8_col12, #T_b3bb3_row9_col1, #T_b3bb3_row10_col5, #T_b3bb3_row10_col14, #T_b3bb3_row11_col4, #T_b3bb3_row11_col5, #T_b3bb3_row11_col10, #T_b3bb3_row14_col10, #T_b3bb3_row17_col14, #T_b3bb3_row18_col14, #T_b3bb3_row19_col4, #T_b3bb3_row19_col5, #T_b3bb3_row19_col8, #T_b3bb3_row19_col11 {
#   background-color: #fffafa;
#   color: #000000;
# }
# #T_b3bb3_row0_col12, #T_b3bb3_row2_col0, #T_b3bb3_row8_col13, #T_b3bb3_row9_col8, #T_b3bb3_row14_col13, #T_b3bb3_row14_col14, #T_b3bb3_row19_col1 {
#   background-color: #fff6f6;
#   color: #000000;
# }
# #T_b3bb3_row1_col0 {
#   background-color: #ff5a5a;
#   color: #f1f1f1;
# }
# #T_b3bb3_row1_col2, #T_b3bb3_row7_col13, #T_b3bb3_row11_col2, #T_b3bb3_row14_col4, #T_b3bb3_row18_col7 {
#   background-color: #ffeaea;
#   color: #000000;
# }
# #T_b3bb3_row6_col0, #T_b3bb3_row8_col5, #T_b3bb3_row14_col5, #T_b3bb3_row15_col2 {
#   background-color: #ffecec;
#   color: #000000;
# }
# #T_b3bb3_row7_col8 {
#   background-color: #ffcece;
#   color: #000000;
# }
# #T_b3bb3_row7_col12, #T_b3bb3_row9_col12 {
#   background-color: #ffdada;
#   color: #000000;
# }
# #T_b3bb3_row8_col0 {
#   background-color: #ff2828;
#   color: #f1f1f1;
# }
# #T_b3bb3_row8_col1, #T_b3bb3_row12_col11 {
#   background-color: #ff9a9a;
#   color: #000000;
# }
# #T_b3bb3_row8_col2 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_b3bb3_row8_col4, #T_b3bb3_row18_col6 {
#   background-color: #ffe6e6;
#   color: #000000;
# }
# #T_b3bb3_row8_col6, #T_b3bb3_row8_col10, #T_b3bb3_row9_col10, #T_b3bb3_row16_col1, #T_b3bb3_row17_col5 {
#   background-color: #fff8f8;
#   color: #000000;
# }
# #T_b3bb3_row8_col7, #T_b3bb3_row14_col7, #T_b3bb3_row16_col13 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_b3bb3_row8_col8, #T_b3bb3_row8_col11, #T_b3bb3_row10_col2, #T_b3bb3_row11_col8, #T_b3bb3_row14_col11, #T_b3bb3_row16_col7, #T_b3bb3_row16_col11, #T_b3bb3_row18_col11, #T_b3bb3_row18_col13 {
#   background-color: #fff2f2;
#   color: #000000;
# }
# #T_b3bb3_row8_col9, #T_b3bb3_row9_col2 {
#   background-color: #ffd8d8;
#   color: #000000;
# }
# #T_b3bb3_row9_col0 {
#   background-color: #ffb2b2;
#   color: #000000;
# }
# #T_b3bb3_row9_col11, #T_b3bb3_row14_col6, #T_b3bb3_row14_col9, #T_b3bb3_row15_col0, #T_b3bb3_row17_col9, #T_b3bb3_row18_col8 {
#   background-color: #ffe8e8;
#   color: #000000;
# }
# #T_b3bb3_row10_col0, #T_b3bb3_row18_col0 {
#   background-color: #ff3232;
#   color: #f1f1f1;
# }
# #T_b3bb3_row11_col12, #T_b3bb3_row12_col8, #T_b3bb3_row13_col8, #T_b3bb3_row18_col2 {
#   background-color: #ff9898;
#   color: #000000;
# }
# #T_b3bb3_row12_col0, #T_b3bb3_row13_col0 {
#   background-color: #ff4c4c;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col1 {
#   background-color: #ff8686;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col2, #T_b3bb3_row13_col2 {
#   background-color: #ffaeae;
#   color: #000000;
# }
# #T_b3bb3_row12_col3, #T_b3bb3_row13_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col4 {
#   background-color: #ff4e4e;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col5 {
#   background-color: #ff3e3e;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col6, #T_b3bb3_row13_col6 {
#   background-color: #ff3c3c;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col7 {
#   background-color: #ff7070;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col9 {
#   background-color: #ffacac;
#   color: #000000;
# }
# #T_b3bb3_row12_col10 {
#   background-color: #ff5c5c;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col12, #T_b3bb3_row13_col12 {
#   background-color: #ffd4d4;
#   color: #000000;
# }
# #T_b3bb3_row12_col13 {
#   background-color: #ff7878;
#   color: #f1f1f1;
# }
# #T_b3bb3_row12_col14 {
#   background-color: #ff8888;
#   color: #f1f1f1;
# }
# #T_b3bb3_row13_col1 {
#   background-color: #ff6c6c;
#   color: #f1f1f1;
# }
# #T_b3bb3_row13_col4 {
#   background-color: #ff4848;
#   color: #f1f1f1;
# }
# #T_b3bb3_row13_col5, #T_b3bb3_row19_col0 {
#   background-color: #ff3838;
#   color: #f1f1f1;

# %% [markdown]
# Find Optimal Number of Clusters

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

sample_indices = np.random.choice(X_processed_famd.shape[0], config.SAMPLE_SIZE_FOR_K_SELECTION, replace=False)
X_sample_famd = X_processed_famd.iloc[sample_indices]

metrics = []
k_list = config.K_CANDIDATES
print(f"Starting k-selection for k in {k_list} on FAMD components...")
for k in k_list:
    km = MiniBatchKMeans(n_clusters=k,
                         n_init='auto',
                         batch_size=config.KMEANS_BATCH_SIZE,
                         random_state=config.RANDOM_STATE)
    labels = km.fit_predict(X_sample_famd)
    sil = silhouette_score(X_sample_famd, labels)
    dbi = davies_bouldin_score(X_sample_famd, labels)
    metrics.append({"k": k, "silhouette": sil, "davies_bouldin": dbi})
    print(f"  k={k}: Silhouette={sil:.4f}, Davies-Bouldin={dbi:.4f}")

metrics_df = pd.DataFrame(metrics)
# Out:
# Starting k-selection for k in [3, 4, 5, 6, 7, 8, 9, 10, 12, 15] on FAMD components...
#   k=3: Silhouette=0.2004, Davies-Bouldin=2.1469
#   k=4: Silhouette=0.2118, Davies-Bouldin=2.0870
#   k=5: Silhouette=0.2195, Davies-Bouldin=2.0481
#   k=6: Silhouette=0.2468, Davies-Bouldin=1.8244
#   k=7: Silhouette=0.2643, Davies-Bouldin=1.6660
#   k=8: Silhouette=0.1831, Davies-Bouldin=1.6535
#   k=9: Silhouette=0.1968, Davies-Bouldin=1.7201
#   k=10: Silhouette=0.2658, Davies-Bouldin=1.4638
#   k=12: Silhouette=0.1969, Davies-Bouldin=1.5321
#   k=15: Silhouette=0.3095, Davies-Bouldin=1.3838

# %%
# Plotting the results
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Cluster Evaluation Metrics on FAMD Components', fontsize=16)

# Davies-Bouldin Score Plot (Elbow Method) - Lower is better
ax1.plot(metrics_df['k'], metrics_df['davies_bouldin'], 'bo-')
ax1.set_xlabel('Number of Clusters (k)')
ax1.set_ylabel('Davies-Bouldin Score')
ax1.set_title('Davies-Bouldin Score for Optimal k')

# Silhouette Score Plot - Higher is better
ax2.plot(metrics_df['k'], metrics_df['silhouette'], 'ro-')
ax2.set_xlabel('Number of Clusters (k)')
ax2.set_ylabel('Average Silhouette Score')
ax2.set_title('Silhouette Analysis for Optimal k')

plt.show()

# %% [markdown]
# ### Compare with Truncated SVD for Dimension Reduction

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import OneHotEncoder

# Define the preprocessor for SVD
svd_preprocessor = ColumnTransformer(
    transformers=[
        ('scaler', StandardScaler(), SEG_NUMERICAL_COLS),
        ('ohe', OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=False), SEG_CATEGORICAL_COLS)
    ],
    remainder='passthrough'
)

# Define the full pipeline with TruncatedSVD
N_COMPONENTS = 15 # Let's use the same number of components for a fair comparison

svd_pipeline = Pipeline(steps=[
    ('preprocessor', svd_preprocessor),
    ('svd', TruncatedSVD(
        n_components=N_COMPONENTS,
        random_state=config.RANDOM_STATE
    ))
])

# Fit the pipeline
print("Fitting TruncatedSVD pipeline...")
X_processed_svd = svd_pipeline.fit_transform(X_segment)
print(f"Shape of data after SVD: {X_processed_svd.shape}")
# Out:
# Fitting TruncatedSVD pipeline...
# Shape of data after SVD: (199523, 15)

# %%
# Get the fitted preprocessor and SVD model from the pipeline
preprocessor_fitted = svd_pipeline.named_steps['preprocessor']
svd_model = svd_pipeline.named_steps['svd']

# Get the feature names after preprocessing (this is crucial)
# The get_feature_names_out() method provides the names of the scaled and OHE columns
feature_names_out = preprocessor_fitted.get_feature_names_out()

# Create a DataFrame of the component loadings (weights)
# The .components_ attribute has a shape of (n_components, n_features)
component_loadings = pd.DataFrame(
    svd_model.components_.T, # Transpose to have features as rows
    index=feature_names_out,
    columns=[f"Component {i}" for i in range(N_COMPONENTS)]
)

print("\n--- Decoding TruncatedSVD Component 0 ---")
print("Top 10 influential features (absolute value):")
display(component_loadings['Component 0'].reindex(component_loadings['Component 0'].abs().sort_values(ascending=False).index).head(10).to_frame())


print("\n--- Decoding TruncatedSVD Component 1 ---")
print("Top 10 influential features (absolute value):")
display(component_loadings['Component 1'].reindex(component_loadings['Component 1'].abs().sort_values(ascending=False).index).head(10).to_frame())
# Out:
# --- Decoding TruncatedSVD Component 0 ---
# Top 10 influential features (absolute value):
#                                                     Component 0
# ohe__citizenship_Native- Born in the United States     0.399857
# ohe__race_White                                        0.376507
# ohe__employment_status_not-in-labor-force              0.360878
# ohe__family_members_under_18_Not in universe           0.290136
# ohe__major_industry_code_Not in universe or chi...     0.265650
# ohe__major_occupation_code_Not in universe             0.265650
# ohe__sex_Male                                          0.217626
# ohe__live_in_this_house_1_year_ago_Not in unive...     0.216675
# ohe__marital_stat_Never married                        0.211949
# ohe__tax_filer_stat_Nonfiler                           0.199125
# --- Decoding TruncatedSVD Component 1 ---
# Top 10 influential features (absolute value):
#                                                    Component 1
# scaler__has_investment_income                         0.403817
# scaler__weeks_worked_in_year                          0.395186
# scaler__age                                           0.372871
# scaler__log_dividends_from_stocks                     0.346929
# ohe__family_members_under_18_Not in universe          0.261442
# scaler__log_capital_gains                             0.231914
# ohe__marital_stat_Married-civilian spouse present     0.205722
# ohe__tax_filer_stat_Nonfiler                         -0.184599
# ohe__tax_filer_stat_Joint both under 65               0.174949
# ohe__education_group_Children                        -0.157841

# %%
# --- Full Styled Loading Matrix ---
max_val = component_loadings.abs().max().max()

styled_svd_loadings = component_loadings.style.background_gradient(
    cmap='bwr', vmin=-max_val, vmax=max_val
).format("{:.3f}")

print("\nFull Loading Matrix for TruncatedSVD Components:")
display(styled_svd_loadings)
# Out:
# Full Loading Matrix for TruncatedSVD Components:
# <style type="text/css">
# #T_d5422_row0_col0, #T_d5422_row1_col11, #T_d5422_row11_col3, #T_d5422_row13_col6, #T_d5422_row19_col3, #T_d5422_row19_col12, #T_d5422_row23_col9, #T_d5422_row25_col3, #T_d5422_row27_col6, #T_d5422_row28_col6, #T_d5422_row29_col4, #T_d5422_row30_col2, #T_d5422_row30_col4, #T_d5422_row31_col6, #T_d5422_row37_col9, #T_d5422_row39_col2, #T_d5422_row41_col3, #T_d5422_row41_col9, #T_d5422_row50_col10, #T_d5422_row57_col9, #T_d5422_row59_col9, #T_d5422_row60_col13, #T_d5422_row64_col3, #T_d5422_row64_col6, #T_d5422_row64_col11, #T_d5422_row73_col6, #T_d5422_row73_col9, #T_d5422_row73_col10, #T_d5422_row78_col5, #T_d5422_row80_col6 {
#   background-color: #f6f6ff;
#   color: #000000;
# }
# #T_d5422_row0_col1, #T_d5422_row4_col6, #T_d5422_row11_col0 {
#   background-color: #ff9696;
#   color: #000000;
# }
# #T_d5422_row0_col2, #T_d5422_row1_col0, #T_d5422_row1_col7, #T_d5422_row15_col11, #T_d5422_row19_col11, #T_d5422_row27_col10, #T_d5422_row29_col14, #T_d5422_row33_col13 {
#   background-color: #e8e8ff;
#   color: #000000;
# }
# #T_d5422_row0_col3, #T_d5422_row3_col6 {
#   background-color: #ff5252;
#   color: #f1f1f1;
# }
# #T_d5422_row0_col4, #T_d5422_row0_col14, #T_d5422_row6_col3, #T_d5422_row23_col2, #T_d5422_row30_col11, #T_d5422_row38_col14, #T_d5422_row43_col14, #T_d5422_row69_col11, #T_d5422_row77_col13 {
#   background-color: #dadaff;
#   color: #000000;
# }
# #T_d5422_row0_col5, #T_d5422_row11_col12 {
#   background-color: #ffd2d2;
#   color: #000000;
# }
# #T_d5422_row0_col6 {
#   background-color: #ffb2b2;
#   color: #000000;
# }
# #T_d5422_row0_col7, #T_d5422_row7_col14, #T_d5422_row15_col2, #T_d5422_row15_col4, #T_d5422_row22_col3, #T_d5422_row25_col9, #T_d5422_row26_col1, #T_d5422_row39_col13, #T_d5422_row69_col3 {
#   background-color: #ffeeee;
#   color: #000000;
# }
# #T_d5422_row0_col8 {
#   background-color: #ffcccc;
#   color: #000000;
# }
# #T_d5422_row0_col9, #T_d5422_row23_col12, #T_d5422_row28_col11, #T_d5422_row29_col0, #T_d5422_row29_col12, #T_d5422_row38_col12, #T_d5422_row80_col11 {
#   background-color: #ffe4e4;
#   color: #000000;
# }
# #T_d5422_row0_col10, #T_d5422_row6_col4, #T_d5422_row9_col0, #T_d5422_row9_col8, #T_d5422_row11_col13, #T_d5422_row13_col9, #T_d5422_row15_col14, #T_d5422_row21_col7, #T_d5422_row22_col11, #T_d5422_row27_col0, #T_d5422_row28_col4, #T_d5422_row33_col1, #T_d5422_row33_col14, #T_d5422_row43_col12, #T_d5422_row55_col9, #T_d5422_row60_col14, #T_d5422_row70_col7, #T_d5422_row78_col1, #T_d5422_row80_col4 {
#   background-color: #fff4f4;
#   color: #000000;
# }
# #T_d5422_row0_col11, #T_d5422_row1_col8, #T_d5422_row21_col3, #T_d5422_row28_col2, #T_d5422_row50_col14, #T_d5422_row80_col2 {
#   background-color: #ffe2e2;
#   color: #000000;
# }
# #T_d5422_row0_col12, #T_d5422_row25_col13, #T_d5422_row28_col13, #T_d5422_row80_col13 {
#   background-color: #babaff;
#   color: #000000;
# }
# #T_d5422_row0_col13 {
#   background-color: #b0b0ff;
#   color: #000000;
# }
# #T_d5422_row1_col1 {
#   background-color: #ff9090;
#   color: #000000;
# }
# #T_d5422_row1_col2, #T_d5422_row1_col13 {
#   background-color: #9494ff;
#   color: #f1f1f1;
# }
# #T_d5422_row1_col3, #T_d5422_row30_col10 {
#   background-color: #a6a6ff;
#   color: #000000;
# }
# #T_d5422_row1_col4, #T_d5422_row1_col10, #T_d5422_row2_col7, #T_d5422_row2_col14, #T_d5422_row4_col3, #T_d5422_row4_col12, #T_d5422_row5_col10, #T_d5422_row10_col9, #T_d5422_row10_col14, #T_d5422_row17_col11, #T_d5422_row19_col9, #T_d5422_row22_col0, #T_d5422_row22_col1, #T_d5422_row22_col2, #T_d5422_row22_col10, #T_d5422_row24_col3, #T_d5422_row26_col4, #T_d5422_row26_col10, #T_d5422_row30_col5, #T_d5422_row34_col9, #T_d5422_row35_col8, #T_d5422_row36_col9, #T_d5422_row38_col0, #T_d5422_row38_col1, #T_d5422_row39_col0, #T_d5422_row39_col11, #T_d5422_row43_col0, #T_d5422_row45_col10, #T_d5422_row50_col1, #T_d5422_row52_col1, #T_d5422_row54_col14, #T_d5422_row55_col0, #T_d5422_row56_col1, #T_d5422_row56_col10, #T_d5422_row56_col12, #T_d5422_row66_col9, #T_d5422_row69_col8, #T_d5422_row74_col12, #T_d5422_row75_col14, #T_d5422_row79_col5, #T_d5422_row79_col6 {
422_row40_col7, #T_d5422_row40_col9, #T_d5422_row40_col10, #T_d5422_row40_col11, #T_d5422_row40_col13, #T_d5422_row40_col14, #T_d5422_row41_col7, #T_d5422_row42_col2, #T_d5422_row42_col3, #T_d5422_row42_col5, #T_d5422_row42_col6, #T_d5422_row42_col7, #T_d5422_row42_col10, #T_d5422_row42_col11, #T_d5422_row42_col14, #T_d5422_row43_col7, #T_d5422_row43_col10, #T_d5422_row44_col5, #T_d5422_row44_col6, #T_d5422_row44_col7, #T_d5422_row44_col11, #T_d5422_row45_col3, #T_d5422_row45_col4, #T_d5422_row45_col5, #T_d5422_row45_col6, #T_d5422_row45_col7, #T_d5422_row45_col8, #T_d5422_row45_col11, #T_d5422_row46_col2, #T_d5422_row46_col3, #T_d5422_row46_col4, #T_d5422_row46_col5, #T_d5422_row46_col6, #T_d5422_row46_col10, #T_d5422_row46_col11, #T_d5422_row47_col11, #T_d5422_row48_col2, #T_d5422_row48_col3, #T_d5422_row48_col5, #T_d5422_row48_col6, #T_d5422_row48_col7, #T_d5422_row48_col9, #T_d5422_row48_col10, #T_d5422_row48_col11, #T_d5422_row48_col12, #T_d5422_row48_col13, #T_d5422_row49_col4, #T_d5422_row49_col6, #T_d5422_row50_col7, #T_d5422_row50_col8, #T_d5422_row50_col11, #T_d5422_row50_col12, #T_d5422_row51_col2, #T_d5422_row51_col3, #T_d5422_row51_col5, #T_d5422_row51_col6, #T_d5422_row51_col7, #T_d5422_row51_col9, #T_d5422_row51_col10, #T_d5422_row51_col11, #T_d5422_row52_col7, #T_d5422_row52_col11, #T_d5422_row53_col2, #T_d5422_row53_col3, #T_d5422_row53_col5, #T_d5422_row53_col6, #T_d5422_row53_col10, #T_d5422_row54_col4, #T_d5422_row54_col6, #T_d5422_row54_col7, #T_d5422_row55_col5, #T_d5422_row55_col7, #T_d5422_row55_col8, #T_d5422_row56_col5, #T_d5422_row56_col7, #T_d5422_row56_col14, #T_d5422_row57_col4, #T_d5422_row57_col5,

# %% [markdown]
# Find Optimal Number of Clusters

# %%
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics import silhouette_score, davies_bouldin_score

sample_indices = np.random.choice(X_processed_svd.shape[0], config.SAMPLE_SIZE_FOR_K_SELECTION, replace=False)
X_sample_svd = X_processed_svd[sample_indices]

metrics = []
k_list = config.K_CANDIDATES
print(f"Starting k-selection for k in {k_list} on SVD components...")
for k in k_list:
    km = MiniBatchKMeans(n_clusters=k,
                         n_init='auto',
                         batch_size=config.KMEANS_BATCH_SIZE,
                         random_state=config.RANDOM_STATE)
    labels = km.fit_predict(X_sample_svd)
    sil = silhouette_score(X_sample_svd, labels)
    dbi = davies_bouldin_score(X_sample_svd, labels)
    metrics.append({"k": k, "silhouette": sil, "davies_bouldin": dbi})
    print(f"  k={k}: Silhouette={sil:.4f}, Davies-Bouldin={dbi:.4f}")

metrics_df = pd.DataFrame(metrics)
# Out:
# Starting k-selection for k in [3, 4, 5, 6, 7, 8, 9, 10, 12, 15] on SVD components...
#   k=3: Silhouette=0.2668, Davies-Bouldin=1.6777
#   k=4: Silhouette=0.2886, Davies-Bouldin=1.5846
#   k=5: Silhouette=0.3293, Davies-Bouldin=1.2521
#   k=6: Silhouette=0.3520, Davies-Bouldin=1.1056
#   k=7: Silhouette=0.3805, Davies-Bouldin=1.0072
#   k=8: Silhouette=0.3554, Davies-Bouldin=1.1370
#   k=9: Silhouette=0.2802, Davies-Bouldin=1.2619
#   k=10: Silhouette=0.2790, Davies-Bouldin=1.2682
#   k=12: Silhouette=0.2418, Davies-Bouldin=1.2743
#   k=15: Silhouette=0.2255, Davies-Bouldin=1.5146

# %%
# Plotting the results
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle('Cluster Evaluation Metrics on SVD Components', fontsize=16)

# Davies-Bouldin Score Plot (Elbow Method) - Lower is better
ax1.plot(metrics_df['k'], metrics_df['davies_bouldin'], 'bo-')
ax1.set_xlabel('Number of Clusters (k)')
ax1.set_ylabel('Davies-Bouldin Score')
ax1.set_title('Davies-Bouldin Score for Optimal k')

# Silhouette Score Plot - Higher is better
ax2.plot(metrics_df['k'], metrics_df['silhouette'], 'ro-')
ax2.set_xlabel('Number of Clusters (k)')
ax2.set_ylabel('Average Silhouette Score')
ax2.set_title('Silhouette Analysis for Optimal k')

plt.show()

# %%
OPTIMAL_K = 6 # Based on the analysis above

kmeans_final = KMeans(n_clusters=OPTIMAL_K, random_state=config.RANDOM_STATE, n_init='auto')
cluster_labels = kmeans_final.fit_predict(X_processed_svd)

# Add the cluster labels back to our original (pre-processed) segmentation data
X_segment['cluster'] = cluster_labels
print(f"Final cluster assignments (for k={OPTIMAL_K}):")
print(X_segment['cluster'].value_counts())
# Out:
# Final cluster assignments (for k=6):
# cluster
# 1    74870
# 0    59949
# 2    35450
# 4    25062
# 5     3802
# 3      390
# Name: count, dtype: int64
# /var/folders/py/bm4kf8_j7tn54t9vvg2pyb5r0000gn/T/ipykernel_86007/1193895757.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_segment['cluster'] = cluster_labels

# %% [markdown]
# Interprete the Result

# %%
# Calculate the mean of numerical features for each cluster
numerical_summary = X_segment.groupby('cluster')[SEG_NUMERICAL_COLS].mean()
# Calculate the mean for the total population for comparison
total_mean = X_segment[SEG_NUMERICAL_COLS].mean()
numerical_summary.loc['Total_Mean'] = total_mean

# Display the summary table, transposing for easier reading
print("Mean of Numerical Features by Cluster:")
display(numerical_summary.T)
# Out:
# Mean of Numerical Features by Cluster:
# cluster                       0           1          2             3  \
# age                    9.358405   37.444838  59.102200     46.869231
# weeks_worked_in_year   0.551435   46.504768   1.437772     47.458974
# wage_per_hour          1.486564  116.349392   0.844908     24.833333
# capital_gains          0.000000    0.000000   0.000000  99999.000000
# capital_losses         0.000000    0.434660   0.453738      0.000000
# dividends_from_stocks  0.016914    0.000668   0.000000   4861.033333
# has_investment_income  0.000183    0.000013   0.000000      1.000000
#
# cluster                          4            5  Total_Mean
# age                      49.365454    43.980800   34.494199
# weeks_worked_in_year     35.158686    41.670174   23.174897
# wage_per_hour            76.492938    79.443188   55.426908
# capital_gains          1904.749302     0.000000  434.718990
# capital_losses            0.320525  1943.266176   37.313788
# dividends_from_stocks  1386.425305   728.097580  197.529533
# has_investment_income     1.000000     0.253288    0.132451

# %%
numerical_summary.T
# Out:
# cluster                       0           1          2             3  \
# age                    9.358405   37.444838  59.102200     46.869231
# weeks_worked_in_year   0.551435   46.504768   1.437772     47.458974
# wage_per_hour          1.486564  116.349392   0.844908     24.833333
# capital_gains          0.000000    0.000000   0.000000  99999.000000
# capital_losses         0.000000    0.434660   0.453738      0.000000
# dividends_from_stocks  0.016914    0.000668   0.000000   4861.033333
# has_investment_income  0.000183    0.000013   0.000000      1.000000
#
# cluster                          4            5  Total_Mean
# age                      49.365454    43.980800   34.494199
# weeks_worked_in_year     35.158686    41.670174   23.174897
# wage_per_hour            76.492938    79.443188   55.426908
# capital_gains          1904.749302     0.000000  434.718990
# capital_losses            0.320525  1943.266176   37.313788
# dividends_from_stocks  1386.425305   728.097580  197.529533
# has_investment_income     1.000000     0.253288    0.132451

# %%
# Normalize the data for fair comparison in the heatmap
scaler = StandardScaler()

# Ensure all column names and index are strings
numerical_summary.columns = numerical_summary.columns.astype(str)
numerical_summary.index = numerical_summary.index.astype(str)

summary_scaled = scaler.fit_transform(numerical_summary.T)  # Transpose to scale features
plt.figure(figsize=(12, 8))
sns.heatmap(
    summary_scaled,
    annot=numerical_summary.T,
    fmt=".1f",
    cmap="coolwarm",
    yticklabels=numerical_summary.columns,
    xticklabels=numerical_summary.index
)
plt.title('Heatmap of Mean Numerical Features by Cluster (Centered & Scaled)', fontsize=16)
plt.ylabel('Numerical Feature')
plt.xlabel('Cluster')
plt.show()

# %%
# Analyze the distribution of categorical features across clusters: 
# add a row of total proportions for comparison
for col in SEG_CATEGORICAL_COLS:
    # Use crosstab to get a frequency table
    contingency_table = pd.crosstab(
        index=X_segment['cluster'],
        columns=X_segment[col],
        normalize='index'  # Normalize by row to get percentages
    )
    
    # Calculate total proportions for the specific column
    total_proportions_series = X_segment[col].value_counts(normalize=True)
    total_proportions = pd.DataFrame([total_proportions_series.values], 
                                   columns=total_proportions_series.index,
                                   index=['Total'])
    
    # Ensure both DataFrames have the same column order
    total_proportions = total_proportions.reindex(columns=contingency_table.columns, fill_value=0)
    
    # Concatenate the contingency table with total proportions
    contingency_table = pd.concat([contingency_table, total_proportions], axis=0)
    
    print(f"\n----- Distribution of '{col}' by Cluster -----")
    print(contingency_table)
    
    # Plotting the distributions
    plt.figure(figsize=(12, 7))
    # Use a diverging color palette to highlight differences from a central point
    sns.heatmap(contingency_table, annot=True, fmt=".2%", cmap="YlGnBu")
    plt.title(f"Proportion of '{col}' within each Cluster")
    plt.ylabel("Cluster")
    plt.xlabel(col)
    plt.show()
    # plt.savefig(os.path.join(config.FIGURE_DIR, f"categorical_distribution_{col}.png"))
# Out:
# ----- Distribution of 'sex' by Cluster -----
# sex      Female      Male
# 0      0.496622  0.503378
# 1      0.493562  0.506438
# 2      0.690860  0.309140
# 3      0.200000  0.800000
# 4      0.464528  0.535472
# 5      0.275644  0.724356
# Total  0.521163  0.478837
# ----- Distribution of 'race' by Cluster -----
